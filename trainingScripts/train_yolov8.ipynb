# %%
from ultralytics import YOLO
import os

#to get the current working directory
directory = os.getcwd()

print(directory)
# Out:
# C:\Users\clara\BachelorThesis_ObjectDetection\trainingScripts

# %% [markdown]
# # Download dataset from Roboflow in yolov8 format

# %%
#!pip install roboflow

#from roboflow import Roboflow
#rf = Roboflow(api_key="cx2jF1GuAVvRWlxk9ZNY")
#project = rf.workspace("fhv").project("chess-pieces-2-6l8qq")
#dataset = project.version(5).download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.134 is required but found version=8.0.193, to fix: `pip install ultralytics==8.0.134`
# ...
# Extracting Dataset Version Zip to Chess-Pieces-2-5 in yolov8:: 100%|███████████| 13188/13188 [00:01<00:00, 10901.59it/s]

# %%
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %%
model = YOLO('yolov8m.pt')
results = model.train(data='/data1/home/tscl/Chess-Pieces-2-5/data.yaml', imgsz=640,  epochs=75, batch=16, cache=True, device=0)
# Out:
# Ultralytics YOLOv8.0.195 🚀 Python-3.8.18 torch-1.12.1+cu113 CUDA:0 (Quadro RTX 6000, 24220MiB)
# WARNING ⚠️ Upgrade to torch>=2.0.0 for deterministic training.
# ...

# %%
# !zip -r runs/detect/train.zip runs/detect/train3
# Out:
#   adding: runs/detect/train3/ (stored 0%)
#   adding: runs/detect/train3/weights/ (stored 0%)
#   adding: runs/detect/train3/weights/last.pt (deflated 8%)
#   adding: runs/detect/train3/weights/best.pt (deflated 8%)
#   adding: runs/detect/train3/args.yaml (deflated 50%)
#   adding: runs/detect/train3/events.out.tfevents.1697098420.srvgpu.3749395.0 (deflated 75%)
#   adding: runs/detect/train3/labels_correlogram.jpg (deflated 35%)
#   adding: runs/detect/train3/labels.jpg (deflated 28%)
#   adding: runs/detect/train3/train_batch0.jpg (deflated 1%)
#   adding: runs/detect/train3/train_batch1.jpg (deflated 2%)
#   adding: runs/detect/train3/train_batch2.jpg (deflated 1%)
#   adding: runs/detect/train3/results.csv (deflated 85%)
#   adding: runs/detect/train3/train_batch23010.jpg (deflated 9%)
#   adding: runs/detect/train3/train_batch23011.jpg (deflated 6%)
#   adding: runs/detect/train3/train_batch23012.jpg (deflated 5%)
# ...

# %% [markdown]
# # Validation
# https://docs.ultralytics.com/modes/val/

# %%
model = YOLO('runs/detect/train2/weights/best.pt')

# Validate the model
metrics = model.val()  # no arguments needed, dataset and settings remembered
metrics.box.map    # map50-95
metrics.box.map50  # map50
metrics.box.map75  # map75
metrics.box.maps   # a list contains map50-95 of each category
# Out:
# Ultralytics YOLOv8.0.196  Python-3.11.5 torch-2.1.0+cpu CPU (11th Gen Intel Core(TM) i5-1135G7 2.40GHz)
# Model summary (fused): 218 layers, 25846708 parameters, 0 gradients, 78.7 GFLOPs
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 4
#       1 model = YOLO('../training_results/runs/train/results_yolov8m/exp/weights/best.pt')
#       3 # Validate the model
# ----> 4 metrics = model.val()  # no arguments needed, dataset and settings remembered
#       5 metrics.box.map    # map50-95
#       6 metrics.box.map50  # map50
#
# File ~\anaconda3\envs\envclara\Lib\site-packages\ultralytics\engine\model.py:276, in Model.val(self, validator, **kwargs)
#     273 args = {**self.overrides, **custom, **kwargs, 'mode': 'val'}  # highest priority args on the right
#     275 validator = (validator or self._smart_load('validator'))(args=args, _callbacks=self.callbacks)
# ...

# %%
# !zip -r runs/detect/train2/val.zip runs/detect/train2/val
